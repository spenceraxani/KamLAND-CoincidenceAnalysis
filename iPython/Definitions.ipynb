# %%
# %matplotlib inline
import os

from scipy.stats import chi2
import itertools
from os.path import expandvars
import glob, sys, pylab,  matplotlib, time, scipy.optimize, math,pickle
import json
import scipy.stats
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import scipy as sp
from pylab import *
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib import rc,gridspec
import matplotlib.cbook as cbook
from scipy.optimize import fsolve
import scipy.optimize as optimization 
from numpy import inf
from scipy.optimize import fsolve
import scipy.optimize as optimization 
from scipy.stats import linregress
from scipy.optimize import curve_fit
from scipy.integrate import quad  
from scipy.optimize import minimize

def getMem():
    print('Ram: '+str(np.round((psutil.Process(os.getpid()).memory_info().rss)/1.E9,4))+'GB')
    return 

import matplotlib
font = {'family': 'serif',
                    'serif':  'Computer Modern Roman',
                    'weight': 200,
                    'size':   20}

matplotlib.rc('font', **font)
plt.rc('text', usetex=True)



linestyle_str = [
     ('solid', 'solid'),      # Same as (0, ()) or '-'
     ('dotted', 'dotted'),    # Same as (0, (1, 1)) or '.'
     ('dashed', 'dashed'),    # Same as '--'
     ('dashdot', 'dashdot')]  # Same as '-.'

linestyle_tuple = [
     ('loosely dotted',        (0, (1, 10))),
     ('dotted',                (0, (1, 1))),
     ('densely dotted',        (0, (1, 1))),

     ('loosely dashed',        (0, (5, 10))),
     ('dashed',                (0, (5, 5))),
     ('densely dashed',        (0, (5, 1))),

     ('loosely dashdotted',    (0, (3, 10, 1, 10))),
     ('dashdotted',            (0, (3, 5, 1, 5))),
     ('densely dashdotted',    (0, (3, 1, 1, 1))),

     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))]


class MyColors():
    def __init__(self):
        self.colors = ['#000000','#1C1C1C','#424242','#6E6E6E','#A4A4A4','#D8D8D8','#E6E6E6','#F2F2F2','#FAFAFA','#FFFFFF',
                       '#4B82B8',
                        '#B8474D',
                        '#95BB58',
                        '#234B7C',
                        '#8060A9',
                        '#53A2CB',
                        '#FC943B']

    def __getitem__(self, item):
        return self.colors[int(item % 7)]

#plt.rc('text', usetex=True)

mycolorsI = ['#000000','#1C1C1C','#424242','#6E6E6E','#A4A4A4','#D8D8D8','#E6E6E6','#F2F2F2','#FAFAFA','#FFFFFF',
            '#4B82B8','#B8474D','#95BB58','#234B7C','#8060A9','#53A2CB','#FC943B']

mycolorsII = ['#000000','#1C1C1C','#424242','#6E6E6E','#A4A4A4','#D8D8D8','#E6E6E6','#F2F2F2','#FAFAFA','#FFFFFF',
            '#00a0c6','#a9deec','#006077','#64a5b5','#f69331','#53A2CB','#FC943B']

mycolorsIII = ['#c70039','#ff5733','#ff8d1a','#ffc300','#eddd53','#add45c','#57c785',
               '#00baad','#2a7b9b','#3d3d6b','#511849','#900c3f','#900c3f']*20


mycolorsIV = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe', 
    '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000', '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080', '#ffffff', '#000000']

colors2 = ['#525564','#74828F', '#96C0CE', '#BEB9B5', '#C25B56', '#FEF6EB']
from matplotlib.colors import LinearSegmentedColormap
vmax = 8.0

cmap = LinearSegmentedColormap.from_list('mycmap', [(0 / vmax, mycolorsIII[0]),
                                                    (1 / vmax, mycolorsIII[1]),
                                                    (2 / vmax, mycolorsIII[2]),
                                                    (3 / vmax, mycolorsIII[3]),
                                                    (4 / vmax, mycolorsIII[4]),
                                                    (5 / vmax, mycolorsIII[5]),
                                                    (6 / vmax, mycolorsIII[6]),
                                                    (7 / vmax, mycolorsIII[7]),
                                                    (8 / vmax, mycolorsIII[8])])
cmap_r = LinearSegmentedColormap.from_list('mycmap', [(0 / vmax, mycolorsIII[8]),
                                                    (1 / vmax, mycolorsIII[7]),
                                                    (2 / vmax, mycolorsIII[6]),
                                                    (3 / vmax, mycolorsIII[5]),
                                                    (4 / vmax, mycolorsIII[4]),
                                                    (5 / vmax, mycolorsIII[3]),
                                                    (6 / vmax, mycolorsIII[2]),
                                                    (7 / vmax, mycolorsIII[1]),
                                                    (8 / vmax, mycolorsIII[0])])
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>
